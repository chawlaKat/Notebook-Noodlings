# %% [markdown]
# <a href="https://colab.research.google.com/github/chawlaKat/Notebook-Noodlings/blob/master/Poster_Samples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Demonstrate value of tooltips, zoom/pan options, filtering, and the comparative scatter I've spent so long developing
#
# What if I start with comparative scatter, then show the value of each feature on that?

# %%
import altair as alt
import bark_to_byte as bb
import scatterable as sc

# %%
cpmp_2015 = bb.arff_to_dataframe('algorithm_runs.arff')

# %%
def join_table(data):
    data.set_index('instance_id', inplace = True),
    data_joined = data.join(data, lsuffix='_x', rsuffix='_y')
    data_joined.reset_index(inplace=True)
    return data_joined

# %% [markdown]
# Filtering: sum of runtimes -> but wait, is that because it times out a lot? -> comparison with only successful runs
#
# ...that's not a good comparision, because if an algorithm fails most runs, it'll just look fast
#
# boxplot of runtimes -> but wait, timeouts, what about when it works -> comparison with only goods
#
# ...except for how that doesn't work on boxplots

# %%
status_dropdown = sc.make_dropdown(cpmp_2015, 'runstatus', 'status-select')

alt.Chart(cpmp_2015).mark_circle().encode(
    x = 'algorithm',
    y = 'runtime'
).add_selection(
    status_dropdown
).transform_filter(
    status_dropdown
)
# Out:
# Chart({
#   data:                      instance_id  repetition  ...   runtime  runstatus
#   0     BF10_cpmp_16_8_77_16_58_13         1.0  ...  3600.000     memout
#   1     BF10_cpmp_16_8_77_16_58_13         1.0  ...  3600.000     memout
#   2     BF10_cpmp_16_8_77_16_58_13         1.0  ...   311.863         ok
#   3     BF10_cpmp_16_8_77_16_58_13         1.0  ...  3600.000    timeout
#   4      BF10_cpmp_16_8_77_16_58_3         1.0  ...  3600.000     memout
#   5      BF10_cpmp_16_8_77_16_58_3         1.0  ...  3600.000     memout
#   6      BF10_cpmp_16_8_77_16_58_3         1.0  ...    78.121         ok
#   7      BF10_cpmp_16_8_77_16_58_3         1.0  ...   600.402         ok
#   8      BF10_cpmp_16_8_77_16_58_8         1.0  ...  3600.000     memout
#   9      BF10_cpmp_16_8_77_16_58_8         1.0  ...  3600.000     memout
#   10     BF10_cpmp_16_8_77_16_58_8         1.0  ...     0.012         ok
#   11     BF10_cpmp_16_8_77_16_58_8         1.0  ...    60.720         ok
#   12    BF11_cpmp_16_8_77_31_47_10         1.0  ...  3600.000     memout
#   13    BF11_cpmp_16_8_77_31_47_10         1.0  ...    92.986         ok
#   14    BF11_cpmp_16_8_77_31_47_10         1.0  ...  2031.039         ok
#   15    BF11_cpmp_16_8_77_31_47_10         1.0  ...   141.857         ok
#   16    BF11_cpmp_16_8_77_31_47_11         1.0  ...  3600.000     memout
#   17    BF11_cpmp_16_8_77_31_47_11         1.0  ...  3600.000     memout
#   18    BF11_cpmp_16_8_77_31_47_11         1.0  ...   422.530         ok
#   19    BF11_cpmp_16_8_77_31_47_11         1.0  ...  3600.000    timeout
#   20    BF11_cpmp_16_8_77_31_47_16         1.0  ...   182.019         ok
#   21    BF11_cpmp_16_8_77_31_47_16         1.0  ...  3600.000     memout
#   22    BF11_cpmp_16_8_77_31_47_16         1.0  ...    66.988         ok
#   23    BF11_cpmp_16_8_77_31_47_16         1.0  ...   249.488         ok
#   24     BF11_cpmp_16_8_77_31_47_6         1.0  ...  3600.000     memout
#   25     BF11_cpmp_16_8_77_31_47_6         1.0  ...  3600.000     memout
#   26     BF11_cpmp_16_8_77_31_47_6         1.0  ...  3600.000    timeout
#   27     BF11_cpmp_16_8_77_31_47_6         1.0  ...  1121.786         ok
#   28     BF11_cpmp_16_8_77_31_47_7         1.0  ...     2.280         ok
#   29     BF11_cpmp_16_8_77_31_47_7         1.0  ...  3600.000     memout
#   ...                          ...         ...  ...       ...        ...
#   2078                cv_data5-8-6         1.0  ...  1610.869         ok
#   2079                cv_data5-8-6         1.0  ...  1532.880         ok
#   2080                cv_data5-8-8         1.0  ...  3600.000     memout
#   2081                cv_data5-8-8         1.0  ...  3600.000     memout
#   2082                cv_data5-8-8         1.0  ...   348.750         ok
#   2083                cv_data5-8-8         1.0  ...   359.362         ok
#   2084               cv_data5-9-10         1.0  ...  3600.000     memout
#   2085               cv_data5-9-10         1.0  ...  3600.000     memout
#   2086               cv_data5-9-10         1.0  ...   675.930         ok
#   2087               cv_data5-9-10         1.0  ...   514.580         ok
#   2088               cv_data5-9-21         1.0  ...  3600.000     memout
#   2089               cv_data5-9-21         1.0  ...  3600.000     memout
#   2090               cv_data5-9-21         1.0  ...   848.305         ok
#   2091               cv_data5-9-21         1.0  ...   608.694         ok
#   2092                cv_data5-9-3         1.0  ...  3600.000     memout
#   2093                cv_data5-9-3         1.0  ...  3600.000     memout
#   2094                cv_data5-9-3         1.0  ...  3600.000    timeout
#   2095                cv_data5-9-3         1.0  ...  3576.584         ok
#   2096               cv_data5-9-32         1.0  ...  3600.000     memout
#   2097               cv_data5-9-32         1.0  ...  3600.000     memout
#   2098               cv_data5-9-32         1.0  ...  3600.000    timeout
#   2099               cv_data5-9-32         1.0  ...  1377.438         ok
#   2100               cv_data5-9-38         1.0  ...  3600.000     memout
#   2101               cv_data5-9-38         1.0  ...  3600.000     memout
#   2102               cv_data5-9-38         1.0  ...  3600.000    timeout
#   2103               cv_data5-9-38         1.0  ...  1108.917         ok
#   2104                cv_data5-9-4         1.0  ...  3600.000     memout
#   2105                cv_data5-9-4         1.0  ...  3600.000     memout
#   2106                cv_data5-9-4         1.0  ...  3253.151         ok
#   2107                cv_data5-9-4         1.0  ...  1466.840         ok
#
#   [2108 rows x 5 columns],
#   encoding: FacetedEncoding({
#     x: X({
#       field: 'algorithm',
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'runtime',
#       type: 'quantitative'
#     })
#   }),
#   mark: 'circle',
#   selection: {'status-select': SelectionDef({
#     bind: BindRadioSelect({
#       input: 'select',
#       options: ['memout', 'ok', 'timeout']
#     }),
#     fields: ['runstatus'],
#     type: 'single'
#   })},
#   transform: [FilterTransform({
#     filter: {'selection': 'status-select'}
#   })]
# })

# %% [markdown]
# Tooltip: huh outlier -> tooltip -> more info
#
# Show algorithm vs runtime

# %%
cpmp_2015 = bb.arff_to_dataframe('algorithm_runs.arff')

alt.Chart(cpmp_2015).mark_circle(size=100).encode(
    x = 'algorithm',
    y = 'runtime',
    tooltip = ['instance_id', 'algorithm', 'runtime', 'runstatus']
).interactive()
# Out:
# Chart({
#   data:                      instance_id  repetition  ...   runtime  runstatus
#   0     BF10_cpmp_16_8_77_16_58_13         1.0  ...  3600.000     memout
#   1     BF10_cpmp_16_8_77_16_58_13         1.0  ...  3600.000     memout
#   2     BF10_cpmp_16_8_77_16_58_13         1.0  ...   311.863         ok
#   3     BF10_cpmp_16_8_77_16_58_13         1.0  ...  3600.000    timeout
#   4      BF10_cpmp_16_8_77_16_58_3         1.0  ...  3600.000     memout
#   5      BF10_cpmp_16_8_77_16_58_3         1.0  ...  3600.000     memout
#   6      BF10_cpmp_16_8_77_16_58_3         1.0  ...    78.121         ok
#   7      BF10_cpmp_16_8_77_16_58_3         1.0  ...   600.402         ok
#   8      BF10_cpmp_16_8_77_16_58_8         1.0  ...  3600.000     memout
#   9      BF10_cpmp_16_8_77_16_58_8         1.0  ...  3600.000     memout
#   10     BF10_cpmp_16_8_77_16_58_8         1.0  ...     0.012         ok
#   11     BF10_cpmp_16_8_77_16_58_8         1.0  ...    60.720         ok
#   12    BF11_cpmp_16_8_77_31_47_10         1.0  ...  3600.000     memout
#   13    BF11_cpmp_16_8_77_31_47_10         1.0  ...    92.986         ok
#   14    BF11_cpmp_16_8_77_31_47_10         1.0  ...  2031.039         ok
#   15    BF11_cpmp_16_8_77_31_47_10         1.0  ...   141.857         ok
#   16    BF11_cpmp_16_8_77_31_47_11         1.0  ...  3600.000     memout
#   17    BF11_cpmp_16_8_77_31_47_11         1.0  ...  3600.000     memout
#   18    BF11_cpmp_16_8_77_31_47_11         1.0  ...   422.530         ok
#   19    BF11_cpmp_16_8_77_31_47_11         1.0  ...  3600.000    timeout
#   20    BF11_cpmp_16_8_77_31_47_16         1.0  ...   182.019         ok
#   21    BF11_cpmp_16_8_77_31_47_16         1.0  ...  3600.000     memout
#   22    BF11_cpmp_16_8_77_31_47_16         1.0  ...    66.988         ok
#   23    BF11_cpmp_16_8_77_31_47_16         1.0  ...   249.488         ok
#   24     BF11_cpmp_16_8_77_31_47_6         1.0  ...  3600.000     memout
#   25     BF11_cpmp_16_8_77_31_47_6         1.0  ...  3600.000     memout
#   26     BF11_cpmp_16_8_77_31_47_6         1.0  ...  3600.000    timeout
#   27     BF11_cpmp_16_8_77_31_47_6         1.0  ...  1121.786         ok
#   28     BF11_cpmp_16_8_77_31_47_7         1.0  ...     2.280         ok
#   29     BF11_cpmp_16_8_77_31_47_7         1.0  ...  3600.000     memout
#   ...                          ...         ...  ...       ...        ...
#   2078                cv_data5-8-6         1.0  ...  1610.869         ok
#   2079                cv_data5-8-6         1.0  ...  1532.880         ok
#   2080                cv_data5-8-8         1.0  ...  3600.000     memout
#   2081                cv_data5-8-8         1.0  ...  3600.000     memout
#   2082                cv_data5-8-8         1.0  ...   348.750         ok
#   2083                cv_data5-8-8         1.0  ...   359.362         ok
#   2084               cv_data5-9-10         1.0  ...  3600.000     memout
#   2085               cv_data5-9-10         1.0  ...  3600.000     memout
#   2086               cv_data5-9-10         1.0  ...   675.930         ok
#   2087               cv_data5-9-10         1.0  ...   514.580         ok
#   2088               cv_data5-9-21         1.0  ...  3600.000     memout
#   2089               cv_data5-9-21         1.0  ...  3600.000     memout
#   2090               cv_data5-9-21         1.0  ...   848.305         ok
#   2091               cv_data5-9-21         1.0  ...   608.694         ok
#   2092                cv_data5-9-3         1.0  ...  3600.000     memout
#   2093                cv_data5-9-3         1.0  ...  3600.000     memout
#   2094                cv_data5-9-3         1.0  ...  3600.000    timeout
#   2095                cv_data5-9-3         1.0  ...  3576.584         ok
#   2096               cv_data5-9-32         1.0  ...  3600.000     memout
#   2097               cv_data5-9-32         1.0  ...  3600.000     memout
#   2098               cv_data5-9-32         1.0  ...  3600.000    timeout
#   2099               cv_data5-9-32         1.0  ...  1377.438         ok
#   2100               cv_data5-9-38         1.0  ...  3600.000     memout
#   2101               cv_data5-9-38         1.0  ...  3600.000     memout
#   2102               cv_data5-9-38         1.0  ...  3600.000    timeout
#   2103               cv_data5-9-38         1.0  ...  1108.917         ok
#   2104                cv_data5-9-4         1.0  ...  3600.000     memout
#   2105                cv_data5-9-4         1.0  ...  3600.000     memout
#   2106                cv_data5-9-4         1.0  ...  3253.151         ok
#   2107                cv_data5-9-4         1.0  ...  1466.840         ok
#
#   [2108 rows x 5 columns],
#   encoding: FacetedEncoding({
#     tooltip: [Tooltip({
#       field: 'instance_id',
#       type: 'nominal'
#     }), Tooltip({
#       field: 'algorithm',
#       type: 'nominal'
#     }), Tooltip({
#       field: 'runtime',
#       type: 'quantitative'
#     }), Tooltip({
#       field: 'runstatus',
#       type: 'nominal'
#     })],
#     x: X({
#       field: 'algorithm',
#       type: 'nominal'
#     }),
#     y: Y({
#       field: 'runtime',
#       type: 'quantitative'
#     })
#   }),
#   mark: MarkDef({
#     size: 100,
#     type: 'circle'
#   }),
#   selection: {'selector002': SelectionDef({
#     bind: 'scales',
#     encodings: ['x', 'y'],
#     type: 'interval'
#   })}
# })

# %%
cpmp_joined = join_table(cpmp_2015)
cpmp_joined.head()
# Out:
#                   instance_id  repetition_x  ... runtime_y  runstatus_y
# 0  BF10_cpmp_16_8_77_16_58_13           1.0  ...  3600.000       memout
# 1  BF10_cpmp_16_8_77_16_58_13           1.0  ...  3600.000       memout
# 2  BF10_cpmp_16_8_77_16_58_13           1.0  ...   311.863           ok
# 3  BF10_cpmp_16_8_77_16_58_13           1.0  ...  3600.000      timeout
# 4  BF10_cpmp_16_8_77_16_58_13           1.0  ...  3600.000       memout
#
# [5 rows x 9 columns]
