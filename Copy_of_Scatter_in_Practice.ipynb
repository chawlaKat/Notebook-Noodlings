# %% [markdown]
# <a href="https://colab.research.google.com/github/chawlaKat/Notebook-Noodlings/blob/master/Copy_of_Scatter_in_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Uses files:
#
#
# *   bark_to_byte.py
# *   scatterable.py
# *   algorithm_runs.arff (from desired scenario)

# %%
pip install liac-arff
# Out:
# ...
#   Created wheel for liac-arff: filename=liac_arff-2.4.0-cp36-none-any.whl size=13335 sha256=ed9e45bb68e034941453207547f08aaaca240dae36971fce6576580c5f5bdf15
#   Stored in directory: /root/.cache/pip/wheels/d1/6a/e7/529dc54d76ecede4346164a09ae3168df358945612710f5203
# Successfully built liac-arff
# ...

# %%
import bark_to_byte as bb
import scatterable as sc
import altair as alt

# %%
alg_source = bb.arff_to_dataframe('algorithm_runs.arff')
alt.data_transformers.disable_max_rows()
# Out:
# DataTransformerRegistry.enable('default')

# %% [markdown]
# #Plain Chart

# %% [markdown]
# make sure it loads, and check run quality measurement name

# %%
# alg_source.head()

# %% [markdown]
# can it make a graph?

# %%
# graph = sc.make_graph(alg_source, 'algorithm', 'solution_quality')

# %%
#graph

# %%
# inter = graph.interactive()
# inter_tip = inter.encode(tooltip = ['instance_id', 'algorithm', 'solution_quality', 'runstatus'])

# #inter_tip

# %%
inter_tip.save('chart_test.html')

# %% [markdown]
# #Join test

# %%
# alg_rekeyed = alg_source.set_index('instance_id')
# alg_joined = alg_rekeyed.join(alg_rekeyed, lsuffix='_x', rsuffix='_y')
# alg_joined.reset_index(inplace = True)
# alg_joined.head()

# %%
# graph = sc.create_comparative_scatter(alg_joined, 'instance_id', 
#                                       'algorithm_x', 'algorithm_y', 
#                                       'runtime_x', 'runtime_y',
#                                       'runstatus_x', 'runstatus_y',
#                                       ['#ffe200', '#f5ffff', '#6600db', '#11182b'])

# %%
# graph

# %% [markdown]
# too big. try lookup instead of join.

# %% [markdown]
# #Lookup test

# %%
#alg_source.head()

# %%
# alt.Chart(alg_source).mark_circle(size=100).encode(
#     x = 'solution_quality',
#     y = 'solution_quality_y:Q'
# ).transform_lookup(
#     lookup = 'instance_id',
#     from_ = alt.LookupData(data = alg_source, key = 'instance_id',
#                            fields = ['solution_quality']
#                           ),
#     as_ = ['solution_quality_y']
# )

# %% [markdown]
# #Fold test

# %% [markdown]
# Setup

# %%
# alg_source.head()
# Out:
#            instance_id  repetition   algorithm  runtime runstatus
# 0  abscisic_bdeu-0.1-2         1.0    astar-ec  7200.00    memout
# 1  abscisic_bdeu-0.1-2         1.0   astar-ed3  7200.00    memout
# 2  abscisic_bdeu-0.1-2         1.0  astar-comp    51.17        ok
# 3  abscisic_bdeu-0.1-2         1.0     cpbayes   115.09        ok
# 4  abscisic_bdeu-0.1-2         1.0     ilp-141  1564.47        ok

# %%
# solution_measure = 'runtime'

# algorithms = list(alg_source['algorithm'].unique())
# columns = list(map(lambda x:(solution_measure+'_'+x), algorithms))
# columns
# Out:
# ['runtime_astar-ec',
#  'runtime_astar-ed3',
#  'runtime_astar-comp',
#  'runtime_cpbayes',
#  'runtime_ilp-141',
#  'runtime_ilp-141-nc',
#  'runtime_ilp-162',
#  'runtime_ilp-162-nc']

# %%
# alg_multi = alg_source.set_index(['instance_id', 'algorithm']).unstack()

# flat_headers = []
# for entry in alg_multi.columns.values:
#   flat_headers.append('_'.join(entry))
  
# alg_multi.columns = flat_headers
# alg_multi.reset_index(inplace= True)

# alg_multi.head()
# Out:
#            instance_id  ...  runstatus_ilp-162-nc
# 0  abscisic_bdeu-0.1-2  ...                    ok
# 1    abscisic_bdeu-1-2  ...                    ok
# 2   abscisic_bdeu-10-2  ...                    ok
# 3  abscisic_bdeu-100-2  ...               timeout
# 4  abscisic_bdeu-100-3  ...               timeout
#
# [5 rows x 25 columns]

# %% [markdown]
# Test 1

# %%
# graph = alt.Chart(alg_multi).transform_fold(
#     columns,
#     as_ = ['column', 'value']
# ).mark_point().encode(
#     x = 'column:N',
#     y = 'value:Q'
# )

# %%
#graph

# %%
# graph.save('chart_test.html')

# %% [markdown]
# Test 1 part 2

# %%
# initial_column = columns[1]

# dropdown = alt.binding_select(options=columns, name='column')
# sel = alt.selection_single(fields=['column'], bind=dropdown, 
#                            init={'column':initial_column})

# select_graph = graph.transform_filter(sel).add_selection(sel)

# %%
# select_graph.save('chart_test.html')

# %% [markdown]
# Test 2

# %%
# graph = alt.Chart(alg_multi).transform_fold(
#     columns,
#     as_ = ['column_x', 'value_x']
# ).transform_fold(
#     columns,
#     as_ = ['column_y', 'value_y']
# ).mark_point().encode(
#     x = 'value_x:Q',
#     y = 'value_y:Q'
# )

# %%
#graph
# Out:
# Chart({
#   data:                  instance_id  ...  runstatus_ilp-162-nc
#   0        abscisic_bdeu-0.1-2  ...                    ok
#   1          abscisic_bdeu-1-2  ...                    ok
#   2         abscisic_bdeu-10-2  ...                    ok
#   3        abscisic_bdeu-100-2  ...               timeout
#   4        abscisic_bdeu-100-3  ...               timeout
#   5             abscisic_bic-2  ...                    ok
#   6     alarm_10000_bdeu-0.1-2  ...                    ok
#   7     alarm_10000_bdeu-0.1-3  ...                    ok
#   8     alarm_10000_bdeu-0.1-4  ...                    ok
#   9     alarm_10000_bdeu-0.1-5  ...                    ok
#   10      alarm_10000_bdeu-1-2  ...                    ok
#   11      alarm_10000_bdeu-1-3  ...                    ok
#   12      alarm_10000_bdeu-1-4  ...                    ok
#   13      alarm_10000_bdeu-1-5  ...                    ok
#   14     alarm_10000_bdeu-10-2  ...                    ok
# ...

# %%
# graph.save('chart_test.html')
